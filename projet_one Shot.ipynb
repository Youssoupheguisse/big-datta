# %%
import requests
from datetime import datetime
index_name = "youssouphe_one_shot" 
json_datas = {
    "location": "14.76, -14.76",
    "typeProduit": "Coca",
    "price": 1000
}
headers = {'Content-Type' : 'application/json' }
response = requests.post( url="http://20.126.103.217:9200/" + index_name + "/_doc" , 
json=json_datas , headers=headers)
response.raise_for_status()
print(response.status_code)
print(response.text)
# Out:
# 201
# {"_index":"youssouf","_type":"_doc","_id":"0BrNPn4BzPxFrIJYWD2y","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":0,"_primary_term":1}

# %%
#mapping
PUT /_index_template/template_youssouf_one
{
   "index_patterns":"youssouphe_one_shot",
   "template":{
      "settings":{
        "number_of_shards": 3,
        "number_of_replicas": 2
      },
   "mappings" : {
      "properties" : {
        "ActualElapsedTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "AirTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "ArrDelay" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "ArrTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CRSArrTime" : {
          "type" : "long"
        },
        "CRSDepTime" : {
          "type" : "long"
        },
        "CRSElapsedTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CancellationCode" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Cancelled" : {
          "type" : "long"
        },
        "CarrierDelay" : {
          "type" : "long"
        },
        "Code" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "DayOfWeek" : {
          "type" : "long"
        },
        "DayofMonth" : {
          "type" : "long"
        },
        "DepDelay" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "DepTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Description" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Dest" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Distance" : {
          "type" : "long"
        },
        "Diverted" : {
          "type" : "long"
        },
        "FlightNum" : {
          "type" : "long"
        },
        "LateAircraftDelay" : {
          "type" : "long"
        },
        "Month" : {
          "type" : "long"
        },
        "NASDelay" : {
          "type" : "long"
        },
        "Origin" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "SecurityDelay" : {
          "type" : "long"
        },
        "TailNum" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "TaxiIn" : {
          "type" : "long"
        },
        "TaxiOut" : {
          "type" : "long"
        },
        "UniqueCarrier" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "WeatherDelay" : {
          "type" : "long"
        },
        "Year" : {
          "type" : "long"
        },
        "airport" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "city" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "country" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "iata" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "lat" : {
          "type" : "float"
        },
        "location" : {
          "type" : "geo_point"
        },
        "long" : {
          "type" : "float"
        },
        "state" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        }
      }
    }
   }
}

# %%
#remplace 
data=open('filghts.json','r')
data_new = open('filghts_formater.json','w')
data_ligne = data.readlines()
e = 0
for i in data:
    data.replace("'", '"')
for i in data_ligne:
    data_new.write('{"index" : { "_index" : "youssouphe_one_shot", "_type" : "_doc", "_id": '+ str(e) +'} }\n')
    i=i.replace("'", '"')
    data_new.write(i)
    e += 1
data.close()
data_new.close()

# %%
# pour poste le fichier sur elastic
import requests

url = "http://20.126.103.217:9200/_bulk"
header = {"Content-Type":"application/json"}
# Data récupère le contenu du fichier json :
data = open("filghts_formater.json", "rb")
data = data.read()
# On crée les data sur notre serveur elasticsearch :
response = requests.post(url,headers=header,data=data)
print(response.status_code)
print(response.content)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b7cba3070b54> in <module>
#       2 with open('filghts.json', 'r') as f:
#       3     for i in format(f):
# ----> 4          f_modif = f.replace("'", '"')
#       5          #f_modif += '{"index":{"_index":"youssouphe_one_shot", "_type":"_doc", "_id":'+i+'}}/n'
#       6         # f_modif += line +"/n"
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'replace'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a4e9a8844d47> in <module>
#       1 import json
#       2 with open('filghts.json', 'r') as f:
# ----> 3     print(json.dumps(f))
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# ...
