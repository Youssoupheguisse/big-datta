# %%
pip install elasticsearch

# %%
from elasticsearch import Elasticsearch 
import requests
import datetime
from requests.models import Response

# %%
import requests
from datetime import datetime
index_name = "youssouphe_2" 
headers = {"Content-Type": "application/json"}

json_datas = {
    "location": "14.76, -14.76",
    "typeProduit": "Coca",
    "price": 1000
}
headers = {'Content-Type' : 'application/json' }
response = requests.post( url="" + index_name + "/_doc" ,json=json_datas,
                   headers=headers)http://20.126.103.217:9200/
response.raise_for_status()
print(response.status_code)
print(response.text)
#mapping
curl -X PUT "http://20.126.103.217:9200/_index_template/template_youssouphe?pretty" -H 'Content-Type: application/json'
{
   "index_patterns":"youssophe2",
   "template":{
      "settings":{
        "number_of_shards": 3,
        "number_of_replicas": 2
          }
       }
      },
{
  "helmi_flights_carriers" : {
    "mappings" : {
      "properties" : {
        "ActualElapsedTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "AirTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "ArrDelay" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "ArrTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CRSArrTime" : {
          "type" : "long"
        },
        "CRSDepTime" : {
          "type" : "long"
        },
        "CRSElapsedTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CancellationCode" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Cancelled" : {
          "type" : "long"
        },
        "CarrierDelay" : {
          "type" : "long"
        },
        "Code" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "DayOfWeek" : {
          "type" : "long"
        },
        "DayofMonth" : {
          "type" : "long"
        },
        "DepDelay" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "DepTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Description" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Dest" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Distance" : {
          "type" : "long"
        },
        "Diverted" : {
          "type" : "long"
        },
        "FlightNum" : {
          "type" : "long"
        },
        "LateAircraftDelay" : {
          "type" : "long"
        },
        "Month" : {
          "type" : "long"
        },
        "NASDelay" : {
          "type" : "long"
        },
        "Origin" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "SecurityDelay" : {
          "type" : "long"
        },
        "TailNum" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "TaxiIn" : {
          "type" : "long"
        },
        "TaxiOut" : {
          "type" : "long"
        },
        "UniqueCarrier" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "WeatherDelay" : {
          "type" : "long"
        },
        "Year" : {
          "type" : "long"
        },
        "airport" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "city" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "country" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "iata" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "lat" : {
          "type" : "float"
        },
        "location" : {
          "type" : "geo_point"
        },
        "long" : {
          "type" : "float"
        },
        "state" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        }
      }
    }
  }
}
# Out:
#   File "<ipython-input-2-0a157168f0fc>", line 13
#     headers=headers)http://20.126.103.217:9200/
#                     ^
# SyntaxError: invalid syntax

# %%
curl -X PUT "http://20.101.123.129:8082/_index_template/template_ibrahima_1?pretty" -H 'Content-Type: application/json' 
-d'{ "index_patterns": ["voiture_ibrahima_1"],
"template": {
"settings": {
"number_of_shards": 1,
"number_of_replicas": 0
},
    "mappings" : {
      "properties" : {
        "ActualElapsedTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "AirTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "ArrDelay" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "ArrTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CRSArrTime" : {
          "type" : "long"
        },
        "CRSDepTime" : {
          "type" : "long"
        },
        "CRSElapsedTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CancellationCode" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Cancelled" : {
          "type" : "long"
        },
        "CarrierDelay" : {
          "type" : "long"
        },
        "Code" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "DayOfWeek" : {
          "type" : "long"
        },
        "DayofMonth" : {
          "type" : "long"
        },
        "DepDelay" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "DepTime" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Description" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Dest" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "Distance" : {
          "type" : "long"
        },
        "Diverted" : {
          "type" : "long"
        },
        "FlightNum" : {
          "type" : "long"
        },
        "LateAircraftDelay" : {
          "type" : "long"
        },
        "Month" : {
          "type" : "long"
        },
        "NASDelay" : {
          "type" : "long"
        },
        "Origin" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "SecurityDelay" : {
          "type" : "long"
        },
        "TailNum" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "TaxiIn" : {
          "type" : "long"
        },
        "TaxiOut" : {
          "type" : "long"
        },
        "UniqueCarrier" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "WeatherDelay" : {
          "type" : "long"
        },
        "Year" : {
          "type" : "long"
        },
        "airport" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "city" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "country" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "iata" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "lat" : {
          "type" : "float"
        },
        "location" : {
          "type" : "geo_point"
        },
        "long" : {
          "type" : "float"
        },
        "state" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        }
      }
    }
  }
# Out:
#   File "<ipython-input-3-7602b471288b>", line 1
#     curl -X PUT "http://20.101.123.129:8082/_index_template/template_ibrahima_1?pretty" -H 'Content-Type: application/json'
#             ^
# SyntaxError: invalid syntax

# %%
import json
fichier = open("filghts.json","rt")
villes = json.loads(fichier.read())
print(villes)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-52650af088fd> in <module>
#       1 import json
#       2 fichier = open("filghts.json","rt")
# ----> 3 villes = json.loads(fichier.read())
#       4 print(villes)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...
